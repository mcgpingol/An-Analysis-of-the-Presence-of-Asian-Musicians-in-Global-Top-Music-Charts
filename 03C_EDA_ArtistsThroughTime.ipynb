# %% [markdown]
# # EDA Part 2

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import re
import datetime
import altair as alt

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 100)

# %%
# Check database
with sqlite3.connect('./pre_processed_data/lab2.db') as conn:
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    
print(cursor.fetchall())
conn.close()
# Out:
# [('artist',), ('billboard_old',), ('spotify_orig',), ('spotify_orig_v2',), ('billboard_back2',), ('wiki_artists',), ('spotify',), ('spotify2',), ('billboard_backup',), ('billboard_artists',), ('billboard',), ('billboard_back3',)]

# %% [markdown]
# ## 1. Query Wikipedia

# %%
# Get Wikipedia artists from database
with sqlite3.connect('./pre_processed_data/lab2.db') as conn:
        q = '''SELECT * FROM wiki_artists
            ''' 
df_wiki = pd.read_sql(q, conn)
conn.close()

# %%
# Check artist names
df_wiki['name'].unique()[10000:11000]
# Out:
# array(['hoàng quyên', 'lynda trang Đài', 'phạm lương thanh trúc',
#        'hoàng hải', 'trần văn khê', 'ha okio', 'big baby gandhi',
#        'monica yunus', 'bua xou mua', 'kesang marstrand', 'angel tang',
#        'alex wong', 'agnes lum', 't.v. carpio', 'larissa lam',
#        'peter moon', 'lee pui ming', 'magdalen hsu-li', 'david oei',
#        'sam tsui', 'rita porfiris', 'masaki liu', 'jason kao hwang',
#        'auliʻi cravalho', 'charles mingus', 'malay', 'huang ruo',
#        'pete miser', 'chen yihan', 'kaiser kuo', 'freddie wong',
#        'catalina yue', 'jadin wong', 'tia carrere', 'carrie ann inaba',
#        'gabriela lena frank', 'ge wang', 'greta kline', 'joe wong', 'zhu',
#        'chloe bennet', 'hao huang', 'yuhua hamasaki', 'cory wong',
#        'alfred apaka', 'john bruce yeh', 'carmit bachar', 'chi cheng',
#        'evelina chao', 'kelis', 'dai-keong lee', 'alan chang',
#        'adam fong', 'dorothy chang', 'naomi yang', 'nicholas phan',
#        'peter mui', 'ben fong-torres', 'leah dizon', 'hoku', 'edit',
#        'the fung brothers', 'jarry lee', 'adrienne lau', 'michael ching',
#        'jimmy wong', 'francis wong', 'don ho', 'anna lacazio',
#        'katherine ho', 'only won', 'sophia yan', 'harry shum jr.',
#        'edwaard liang', 'chester see', 'telly leung',
#        'shanghai restoration project', 'dawn xiana moon', 'anya phillips',
#        'chino rodriguez', 'kui lee', 'mc jin', 'gwendoline yeo',
#        'jane lui', 'walshy fire', 'nancy zhou', 'jeff chan', 'daniel ho',
#        'jaeson ma', 'tina guo', 'dawen', 'janel parrish', 'fred ho',
#        'frank huang', 'annie lin', 'fresh kid ice', 'jon jang',
#        'jahja ling', 'manika', 'tony williams', 'eugene f. castillo',
#        'charmaine clamor', 'nicholas vasallo', 'nani alapai',
#        'asia nitollano', 'jay r', 'cheesa', 'dominic fike',
#        'nicole scherzinger', 'manskee', 'dj qbert', 'kate earl',
#        'larry g', 'june marieezy', 'zarah', 'chad hugo', 'cassie ventura',
#        'asia cruise', 'bert nievera', 'mike inez', 'olivia rodrigo',
#        'regina zernay roberts', 'dj clay', 'joe bataan',
#        'mariqueen maandig', 'ted sablay', 'billy hinsche',
#        'kyle alandy amor', 'noah bernardo', 'renaldo lapuz',
#        'susie ibarra', 'neal mccoy', 'toro y moi', 'shawn wasabi',
#        'mix master mike', 'hailee steinfeld', 'lalaine', 'h.e.r.',
#        'loretta ables sayre', 'ryan buendia', 'charlyne yi', 'jay som',
#        'angelica hale', 'aj rafael', 'lena hall', "lil' eddie",
#        'lehua sandbo', 'lori barbero', 'angel faith', 'jessica sanchez',
#        'bob parlocha', 'bruno mars', 'wendy woo', 'ahrue luster',
#        'elle king', 'bobby enriquez', 'malaya watson', 'josie zec',
#        'kris lawrence', 'larry ramos', 'jon irabagon', 'jasmine trias',
#        'guji lorenzana', 'john florencio', 'joseph vincent',
#        'gabe baltazar', 'rachael lampa', 'tippy dos santos', 'jyro xhan',
#        'jeff bernat', 'danny barcelona', 'victor noriega', 'thia megia',
#        'jerome fontamillas', 'kirk hammett', 'hanni el khatib',
#        'matthew santos', 'roshon fegan', 'sugar pie desanto',
#        'joyo velarde', 'david pajo', 'vanessa hudgens', 'anna akana',
#        'joey santiago', 'illmind', 'sophia montecarlo', 'bejun mehta',
#        'sanjay mishra', 'debelah morgan', 'vivek maddala',
#        'niharika desai', 'jayanthi kyle', 'falu', 'asha puthli',
#        'kamala sankaram', 'shirish korde', 'zarin mehta', 'vasant rai',
#        'kim thayil', 'savan kotecha', 'faris mcreynolds',
#        'jasmine sandlas', 'thara prashad', 'ravi hutheesing',
#        'arun luthra', 'tony kanal', 'dhamakapella', 'mehli mehta',
#        'vijay gupta', 'tanmoy bose', 'rahul desikan', 'sandip burman',
#        'tina sugandh', 'bindu subramaniam', 'norah jones',
#        'rozonda thomas', 'rajiv dhall', 'dj ravidrums', 'shilpa ray',
#        'reena esmail', 'alap momin', 'jeff bhasker', 'ramesh srivastava',
#        'kush arora', 'vijay iyer', 'jasmine solano', 'armand van helden',
#        'michelle branch', 'dan the automator', 'dj heavygrinder',
#        'jhené aiko', 'shoji kameda', 'janis tanaka', 'miya folick',
#        'mia doi todd', 'bianca ryan', 'mark izu', 'mila j',
#        'pj hirabayashi', 'mike shinoda', 'meiko', 'judith hill',
#        'shinji eshima', 'gerald oshita', 'tomo yasuda', 'carole kai',
#        'charlie tagawa', 'yuki chikudate', 'tak shindo', 'james iha',
#        'justin nozuka', 'jeff kashiwa', 'nikki', 'miles okazaki',
#        'jadagrace', 'masayuki koga', 'masa fukuda', 'ben jorgensen',
#        'audrey marrs', 'seiichi tanaka', 'johnny mori', 'caroline lufkin',
#        'ryo okumoto', 'dave suzuki', 'michiko toyama', 'kenji williams',
#        'money mark', 'jeff labar', 'ethel azama', 'kina grannis',
#        'bryan mantia', 'maryanne ito', 'masanori mark christianson',
#        'hiroshima', 'akira tana', 'toshi yano', 'tao rodríguez-seeger',
#        'glenn horiuchi', 'conan gray', 'sean lennon', 'hayley kiyoko',
#        'jake shimabukuro', 'stephanie', 'lemon drop kick', 'kei akagi',
#        'kyoko kitamura', 'pat suzuki', 'anthony brown', 'steve aoki',
#        'shoji tabuchi', 'stephen m. sano', 'randy oda', 'hiro yamamoto',
#        'james shigeta', 'ken ueno', 'ray iwazumi', 'steve jablonsky',
#        'towkio', 'suzee ikeda', 'mika horiuchi', 'uffie', 'kenny endo',
#        'gia gunn', 'yvonne elliman', 'joe inoue', 'andrew koji shiraki',
#        'gene ess', 'nano', 'tatsu aoki', 'masakazu yoshizawa',
#        'kishi bashi', 'hana shimozumi', 'mayuka thaïs', 'nic endo',
#        'harry urata', 'lyrics born', 'rigel gemini', 'asako hirabayashi',
#        'gryffin', 'linda mcdonald', 'jake e. lee', 'takayo fischer',
#        'dumbfoundead', 'michael kang', 'bernard park', 'jeff schroeder',
#        'lee hyun-woo', 'grace kelly', 'yoo seung-jun', 'kero one',
#        'jae chong', 'joon lee', 'nosaj thing', 'sooyoung park',
#        'run river north', 'kathleen kim', 'mike park', 'amerie',
#        'susie suh', 'jun sung ahn', 'tokimonsta', 'megan lee', 'kodi lee',
#        'moses archuleta', 'johnny yong bosch', 'john park',
#        'lucia micarelli', 'paul pesco', 'priscilla ahn',
#        'japanese breakfast', 'anderson .paak', 'michelle zauner',
#        'ex-plicit linez', 'kato', 'aja kim', 'margaret cho', 'mia park',
#        'sam kim', 'steven lee', 'jinu', 'yaeji', 'kimberly goss',
#        'eugene park', 'karen o', 'lee soo-jung', 'bora yoon',
#        'mina chang', 'yoonil auh', 'john myung', 'shane gallagher',
#        'david choi', 'g.soul', 'eric nam', 'jiha lee', 'heesun lee',
#        'joe hahn', 'david park', 'taebin', 'nicky lee', 'clara chung',
#        'lazarus', 'the kominas', 'mr. capone-e', 'aqsa', 'krewella',
#        'fareed haque', 'nadia ali', 'arooj aftab', 'salman ahmad',
#        'dhoombros', 'vienna teng', 'kaila yu', 'chihchun chi-sun lee',
#        'wang leehom', 'mree', 'lynn chang', 'jen shyu', 'mei-ann chen',
#        'cho-liang lin', 'helen sung', 'robert chen', 'david chan',
#        'hu nai-yuan', 'wu han', 'sirena huang', 'christine wu',
#        'joel fan', 'helen huang', 'carolyn kuan'], dtype=object)

# %%
# Check artist country
df_wiki['country'].unique()
# Out:
# array(['South Korean', 'Bruneian', 'Burmese', 'Cambodian', 'Chinese',
#        'East Timorese', 'Filipino', 'Indonesian', 'Japanese', 'Laotian',
#        'Malaysian', 'Mongolian', 'Singaporean', 'Thai', 'Vietnamese',
#        'Bangladeshi American', 'Laotian American', 'Tibetan American',
#        'Chinese American', 'Filipino American', 'Indian American',
#        'Indonesian American', 'Japanese American', 'Korean American',
#        'Pakistani American', 'Taiwanese American'], dtype=object)

# %% [markdown]
# ## 2. Query Billboard

# %%
# Get Billboard charts results
with sqlite3.connect('./pre_processed_data/lab2.db') as conn:
        q = '''SELECT * FROM billboard
            ''' 
df_billboard = pd.read_sql(q, conn)
conn.close()

# %%
# Check the query
df_billboard.head()
# Out:
#         chartname        date              song      artist  rank
# 0  weekly_hot_100  2011-01-03           Grenade  bruno mars     1
# 1  weekly_hot_100  2011-01-03          Firework  katy perry     2
# 2  weekly_hot_100  2011-01-03     We R Who We R       ke$ha     3
# 3  weekly_hot_100  2011-01-03   What's My Name?     rihanna     4
# 4  weekly_hot_100  2011-01-03  Raise Your Glass        p!nk     5

# %%
# Check the charts that were scraped
df_billboard['chartname'].unique()
# Out:
# array(['weekly_hot_100', 'weekly_billboard_200',
#        'weekly_billboard_global_200',
#        'weekly_billboard_global_exclUS_200'], dtype=object)

# %%
# Create the month_year and Asian column
df_billboard['month_yr'] = pd.to_datetime(
    df_billboard['date']).dt.to_period('M')
df_billboard["asian"] = df_billboard["artist"].isin(df_wiki['name'])

df_billboard.head()
# Out:
#         chartname        date              song      artist  rank month_yr  \
# 0  weekly_hot_100  2011-01-03           Grenade  bruno mars     1  2011-01
# 1  weekly_hot_100  2011-01-03          Firework  katy perry     2  2011-01
# 2  weekly_hot_100  2011-01-03     We R Who We R       ke$ha     3  2011-01
# 3  weekly_hot_100  2011-01-03   What's My Name?     rihanna     4  2011-01
# 4  weekly_hot_100  2011-01-03  Raise Your Glass        p!nk     5  2011-01
#
#    asian
# 0   True
# 1  False
# 2  False
# 3  False
# 4  False

# %%
# Combine billboard table and Wiki table
df_billboard = pd.merge(df_billboard, df_wiki, 
                        left_on='artist', right_on='name', how="left")

# %%
# Create a subset of the Weekly Hot 100 chart
df_hot_100 = df_billboard[df_billboard['chartname'] == 'weekly_hot_100']

# %%
# Create a subset of the Billboard Global 200
df_global_bb = (df_billboard[df_billboard['chartname'] == 
                             'weekly_billboard_global_200'])

df_global_bb = df_global_bb[df_global_bb['rank'] <= 100]

# %% [markdown]
# ## 3. Query Spotify

# %%
# Get Spotify charts results
with sqlite3.connect('./pre_processed_data/lab2.db') as conn:
        q = '''SELECT * FROM spotify
            ''' 
df_spotify = pd.read_sql(q, conn)
conn.close()

# %%
# Check the query obtained
df_spotify.head()
# Out:
#   chartname chartfreq        date  region  rank                          song  \
# 0   viral50     daily  2017-01-05  global     1                      Sigurado
# 1   viral50     daily  2017-01-05  global     2  Fill Me In - AFTR:HRS Mixcut
# 2   viral50     daily  2017-01-05  global     2  Fill Me In - AFTR:HRS Mixcut
# 3   viral50     daily  2017-01-05  global     3                  Losing Sleep
# 4   viral50     daily  2017-01-05  global     4                      Deu Onda
#
#                           artist         artist2  stream_count
# 0              by Up Dharma Down  up dharma down             0
# 1  by Loud Luxury, Ryan Shepherd     loud luxury             0
# 2  by Loud Luxury, Ryan Shepherd   ryan shepherd             0
# 3                       by Vorsa           vorsa             0
# 4                      by MC G15          mc g15             0

# %%
# Create new column for month_yr and Asians
df_spotify['month_yr'] = pd.to_datetime(df_spotify['date']).dt.to_period('M')
df_spotify["asian"] = df_spotify["artist2"].isin(df_wiki['name'])

# %%
# Combine the dataframe with the Wikipedia data
df_spotify2 = pd.merge(df_spotify, df_wiki, 
                       left_on='artist2', right_on='name', how='left')
df_spotify2
# Out:
#         chartname chartfreq        date  region  rank  \
# 0         viral50     daily  2017-01-05  global     1
# 1         viral50     daily  2017-01-05  global     2
# 2         viral50     daily  2017-01-05  global     2
# 3         viral50     daily  2017-01-05  global     3
# 4         viral50     daily  2017-01-05  global     4
# ...           ...       ...         ...     ...   ...
# 1241745    top200    weekly  2021-07-23      us   196
# 1241746    top200    weekly  2021-07-23      us   197
# 1241747    top200    weekly  2021-07-23      us   198
# 1241748    top200    weekly  2021-07-23      us   199
# 1241749    top200    weekly  2021-07-23      us   200
#
#                                         song                         artist  \
# 0                                   Sigurado              by Up Dharma Down
# 1               Fill Me In - AFTR:HRS Mixcut  by Loud Luxury, Ryan Shepherd
# 2               Fill Me In - AFTR:HRS Mixcut  by Loud Luxury, Ryan Shepherd
# 3                               Losing Sleep                       by Vorsa
# 4                                   Deu Onda                      by MC G15
# ...                                      ...                            ...
# 1241745                              Hold On               by Justin Bieber
# 1241746                          I Like That                       by Bazzi
# 1241747                                   21                      by Polo G
# 1241748                            Heartless                  by Kanye West
# 1241749  The Way Life Goes (feat. Oh Wonder)                by Lil Uzi Vert
#
#                 artist2  stream_count month_yr  asian name country lineage
# 0        up dharma down             0  2017-01  False  NaN     NaN     NaN
# 1           loud luxury             0  2017-01  False  NaN     NaN     NaN
# 2         ryan shepherd             0  2017-01  False  NaN     NaN     NaN
# 3                 vorsa             0  2017-01  False  NaN     NaN     NaN
# 4                mc g15             0  2017-01  False  NaN     NaN     NaN
# ...                 ...           ...      ...    ...  ...     ...     ...
# 1241745   justin bieber       1419124  2021-07  False  NaN     NaN     NaN
# 1241746           bazzi       1418767  2021-07  False  NaN     NaN     NaN
# 1241747          polo g       1410427  2021-07  False  NaN     NaN     NaN
# 1241748      kanye west       1409485  2021-07  False  NaN     NaN     NaN
# 1241749    lil uzi vert       1404108  2021-07  False  NaN     NaN     NaN
#
# [1241750 rows x 14 columns]

# %%
# Obtain a subset of the Spotify Top 200 Global charts
df_spotify_top200_global = df_spotify2[df_spotify2['chartname'] == 'top200']
df_spotify_top200_global = df_spotify_top200_global[
    df_spotify_top200_global['chartfreq'] == 'weekly']
df_spotify_top200_global = df_spotify_top200_global[
    df_spotify_top200_global['region'] == 'global']
df_spotify_top200_global = df_spotify_top200_global[
    df_spotify_top200_global['rank'] <= 100]
df_spotify_top200_global.head()
# Out:
#         chartname chartfreq        date  region  rank  \
# 1118434    top200    weekly  2016-12-23  global     1
# 1118435    top200    weekly  2016-12-23  global     1
# 1118436    top200    weekly  2016-12-23  global     2
# 1118437    top200    weekly  2016-12-23  global     2
# 1118438    top200    weekly  2016-12-23  global     3
#
#                                             song                       artist  \
# 1118434                                  Starboy     by The Weeknd, Daft Punk
# 1118435                                  Starboy     by The Weeknd, Daft Punk
# 1118436                                   Closer  by The Chainsmokers, Halsey
# 1118437                                   Closer  by The Chainsmokers, Halsey
# 1118438  Rockabye (feat. Sean Paul & Anne-Marie)              by Clean Bandit
#
#                   artist2  stream_count month_yr  asian name country lineage
# 1118434        the weeknd      25286465  2016-12  False  NaN     NaN     NaN
# 1118435         daft punk      25286465  2016-12  False  NaN     NaN     NaN
# 1118436  the chainsmokers      22047697  2016-12  False  NaN     NaN     NaN
# 1118437            halsey      22047697  2016-12  False  NaN     NaN     NaN
# 1118438      clean bandit      19794482  2016-12  False  NaN     NaN     NaN

# %%
# Obtain a subset of the Spotify Top 200 US charts
df_spotify_top200_us = df_spotify2[df_spotify2['chartname'] == 'top200']
df_spotify_top200_us = df_spotify_top200_us[
    df_spotify_top200_us['chartfreq'] == 'weekly']
df_spotify_top200_us = df_spotify_top200_us[
    df_spotify_top200_us['region'] == 'us']
df_spotify_top200_us = df_spotify_top200_us[
    df_spotify_top200_us['rank'] <= 100]
df_spotify_top200_us
# Out:
#         chartname chartfreq        date region  rank  \
# 1183967    top200    weekly  2016-12-23     us     1
# 1183968    top200    weekly  2016-12-23     us     2
# 1183969    top200    weekly  2016-12-23     us     3
# 1183970    top200    weekly  2016-12-23     us     3
# 1183971    top200    weekly  2016-12-23     us     4
# ...           ...       ...         ...    ...   ...
# 1241634    top200    weekly  2021-07-23     us    96
# 1241635    top200    weekly  2021-07-23     us    97
# 1241636    top200    weekly  2021-07-23     us    98
# 1241637    top200    weekly  2021-07-23     us    99
# 1241638    top200    weekly  2021-07-23     us   100
#
#                                                       song  \
# 1183967                                          Fake Love
# 1183968                Bad and Boujee (feat. Lil Uzi Vert)
# 1183969                                            Starboy
# 1183970                                            Starboy
# 1183971                                      Black Beatles
# ...                                                    ...
# 1241634  Whats Poppin (feat. DaBaby, Tory Lanez & Lil W...
# 1241635                       ROCKSTAR (feat. Roddy Ricch)
# 1241636                           Stoned at the Nail Salon
# 1241637                       1 step forward, 3 steps back
# 1241638                            Welcome to the Internet
#
#                               artist         artist2  stream_count month_yr  \
# 1183967                     by Drake           drake       8618267  2016-12
# 1183968                     by Migos           migos       7946032  2016-12
# 1183969     by The Weeknd, Daft Punk      the weeknd       7738517  2016-12
# 1183970     by The Weeknd, Daft Punk       daft punk       7738517  2016-12
# 1183971  by Rae Sremmurd, Gucci Mane    rae sremmurd       6209336  2016-12
# ...                              ...             ...           ...      ...
# 1241634               by Jack Harlow     jack harlow       1945998  2021-07
# 1241635                    by DaBaby          dababy       1945182  2021-07
# 1241636                     by Lorde           lorde       1942072  2021-07
# 1241637            by Olivia Rodrigo  olivia rodrigo       1936744  2021-07
# 1241638                by Bo Burnham      bo burnham       1925765  2021-07
#
#          asian            name            country      lineage
# 1183967  False             NaN                NaN          NaN
# 1183968  False             NaN                NaN          NaN
# 1183969  False             NaN                NaN          NaN
# 1183970  False             NaN                NaN          NaN
# 1183971  False             NaN                NaN          NaN
# ...        ...             ...                ...          ...
# 1241634  False             NaN                NaN          NaN
# 1241635  False             NaN                NaN          NaN
# 1241636  False             NaN                NaN          NaN
# 1241637   True  olivia rodrigo  Filipino American  Mixed Asian
# 1241638  False             NaN                NaN          NaN
#
# [28841 rows x 14 columns]

# %%
# Create a new column to get unique chart name
df_spotify_top200_us['chart_name'] = (
    df_spotify_top200_us['chartname'] +
    '_' +
    df_spotify_top200_us['region'])
    
df_spotify_top200_global['chart_name'] = (
    df_spotify_top200_global['chartname'] +
    '_' +
    df_spotify_top200_global['region'])
    
df_hot_100['chart_name'] = df_hot_100['chartname']
df_global_bb['chart_name'] = df_global_bb['chartname']
# Out:
# <ipython-input-19-82659c5da919>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hot_100['chart_name'] = df_hot_100['chartname']

# %% [markdown]
# ## Visualization Preparation

# %%
# Combine all charts into one DataFrame
charts = [df_spotify_top200_us, df_spotify_top200_global,
          df_hot_100, df_global_bb]
chart_names = ['Spotify Top 200 US', 'Spotify Top 200 Global', 
                     'Billboard Hot 100', 'Billboard Global 200']
df_charts = pd.DataFrame()

for i in charts:
    new_df = (i.groupby(['month_yr', 'chart_name'])['asian'].sum()
              .to_frame())
    df_charts = pd.concat([df_charts, new_df], axis=1)
    
df_charts.columns = chart_names
df_charts.reset_index(inplace=True)
df_charts.drop(columns=['chart_name'], inplace=True)
df_charts.set_index('month_yr')
df_charts['month_yr'] = df_charts['month_yr'].astype(str)

# %%
# Prepare DataFrame for plotting
df_charts_melt = df_charts[df_charts['month_yr'] >= '2016-12']
df_charts_melt = df_charts_melt.melt(
    id_vars='month_yr', value_vars=chart_names).dropna()
df_charts_melt.head()
# Out:
#    month_yr            variable  value
# 1   2016-12  Spotify Top 200 US   10.0
# 4   2017-01  Spotify Top 200 US   16.0
# 7   2017-02  Spotify Top 200 US   20.0
# 10  2017-03  Spotify Top 200 US   19.0
# 13  2017-04  Spotify Top 200 US   13.0

# %%
# Save DataFrame to csv
df_charts_melt.to_csv('./post_processed_data/counts_over_time.csv')

# %%
# Creates a plot of Asian artists count in the charts over time
df_charts_melt = pd.read_csv('./post_processed_data/counts_over_time.csv')

chart_line = alt.Chart(df_charts_melt, 
                       title="Asians in Different Music Charts through Time"
).mark_line().encode(
    x=alt.X('month_yr', axis=alt.Axis(title='Date')),
    y=alt.Y('value', scale=alt.Scale(domain=[0, 70]),
            axis=alt.Axis(title='Number of Time in Chart')),
    color=alt.Color('variable', legend=alt.Legend(title="Music Chart")),
    strokeDash='variable',
).properties(
    width=800,
    height=300
).configure_axis(
    labelFontSize=12,
    titleFontSize=14
).configure_title(
    fontSize=18,
    offset=5,                          
    orient='top',
    anchor='middle')

chart_line

# https://altair-viz.github.io/user_guide/customization.html
# Out:
# alt.Chart(...)

# %%
# Combine the DataFrame in terms of lineage
df_charts_orig = pd.DataFrame()

for i in charts:
    lineage_count = i.groupby(['month_yr', 'lineage']).size().to_frame()
    df_charts_orig = pd.concat([df_charts_orig, lineage_count], axis=1)
    
df_charts_orig.columns = chart_names
df_charts_orig = (df_charts_orig.reset_index()
                  .set_index('month_yr').loc['2020-09':])
df_charts_orig.head()
# Out:
#               lineage  Spotify Top 200 US  Spotify Top 200 Global  \
# month_yr
# 2020-09         Asian                26.0                    20.0
# 2020-09   Mixed Asian                 4.0                     4.0
# 2020-10         Asian                24.0                    38.0
# 2020-10   Mixed Asian                 6.0                     5.0
# 2020-11         Asian                17.0                    29.0
#
#           Billboard Hot 100  Billboard Global 200
# month_yr
# 2020-09                 4.0                   7.0
# 2020-09                 4.0                   2.0
# 2020-10                 5.0                  32.0
# 2020-10                 4.0                   4.0
# 2020-11                11.0                  53.0

# %%
# Prepare the DataFrame for plotting
df_orig_melt = df_charts_orig.reset_index().melt(id_vars=['month_yr', 
                                                          'lineage'])
df_orig_melt['month_yr'] = df_orig_melt['month_yr'].astype(str)
df_orig_melt
# Out:
#    month_yr      lineage                variable  value
# 0   2020-09        Asian      Spotify Top 200 US   26.0
# 1   2020-09  Mixed Asian      Spotify Top 200 US    4.0
# 2   2020-10        Asian      Spotify Top 200 US   24.0
# 3   2020-10  Mixed Asian      Spotify Top 200 US    6.0
# 4   2020-11        Asian      Spotify Top 200 US   17.0
# 5   2020-11  Mixed Asian      Spotify Top 200 US    4.0
# 6   2020-12        Asian      Spotify Top 200 US    6.0
# 7   2020-12  Mixed Asian      Spotify Top 200 US    4.0
# 8   2021-01        Asian      Spotify Top 200 US   12.0
# 9   2021-01  Mixed Asian      Spotify Top 200 US   11.0
# 10  2021-02        Asian      Spotify Top 200 US   13.0
# 11  2021-02  Mixed Asian      Spotify Top 200 US    8.0
# 12  2021-03        Asian      Spotify Top 200 US    5.0
# 13  2021-03  Mixed Asian      Spotify Top 200 US   16.0
# 14  2021-04        Asian      Spotify Top 200 US    NaN
# 15  2021-04  Mixed Asian      Spotify Top 200 US   28.0
# 16  2021-05        Asian      Spotify Top 200 US    8.0
# 17  2021-05  Mixed Asian      Spotify Top 200 US   40.0
# 18  2021-06        Asian      Spotify Top 200 US    8.0
# 19  2021-06  Mixed Asian      Spotify Top 200 US   52.0
# 20  2021-07        Asian      Spotify Top 200 US   11.0
# 21  2021-07  Mixed Asian      Spotify Top 200 US   51.0
# 22  2020-09        Asian  Spotify Top 200 Global   20.0
# 23  2020-09  Mixed Asian  Spotify Top 200 Global    4.0
# 24  2020-10        Asian  Spotify Top 200 Global   38.0
# 25  2020-10  Mixed Asian  Spotify Top 200 Global    5.0
# 26  2020-11        Asian  Spotify Top 200 Global   29.0
# 27  2020-11  Mixed Asian  Spotify Top 200 Global    4.0
# 28  2020-12        Asian  Spotify Top 200 Global   14.0
# 29  2020-12  Mixed Asian  Spotify Top 200 Global    4.0
# 30  2021-01        Asian  Spotify Top 200 Global   15.0
# 31  2021-01  Mixed Asian  Spotify Top 200 Global    9.0
# 32  2021-02        Asian  Spotify Top 200 Global   11.0
# 33  2021-02  Mixed Asian  Spotify Top 200 Global    8.0
# 34  2021-03        Asian  Spotify Top 200 Global    8.0
# 35  2021-03  Mixed Asian  Spotify Top 200 Global   16.0
# 36  2021-04        Asian  Spotify Top 200 Global   11.0
# 37  2021-04  Mixed Asian  Spotify Top 200 Global   30.0
# 38  2021-05        Asian  Spotify Top 200 Global   12.0
# 39  2021-05  Mixed Asian  Spotify Top 200 Global   40.0
# 40  2021-06        Asian  Spotify Top 200 Global   14.0
# 41  2021-06  Mixed Asian  Spotify Top 200 Global   55.0
# 42  2021-07        Asian  Spotify Top 200 Global   15.0
# 43  2021-07  Mixed Asian  Spotify Top 200 Global   45.0
# 44  2020-09        Asian       Billboard Hot 100    4.0
# 45  2020-09  Mixed Asian       Billboard Hot 100    4.0
# 46  2020-10        Asian       Billboard Hot 100    5.0
# 47  2020-10  Mixed Asian       Billboard Hot 100    4.0
# 48  2020-11        Asian       Billboard Hot 100   11.0
# 49  2020-11  Mixed Asian       Billboard Hot 100    5.0
# 50  2020-12        Asian       Billboard Hot 100    6.0
# 51  2020-12  Mixed Asian       Billboard Hot 100    2.0
# 52  2021-01        Asian       Billboard Hot 100    4.0
# 53  2021-01  Mixed Asian       Billboard Hot 100    6.0
# 54  2021-02        Asian       Billboard Hot 100    5.0
# 55  2021-02  Mixed Asian       Billboard Hot 100   10.0
# 56  2021-03        Asian       Billboard Hot 100    5.0
# 57  2021-03  Mixed Asian       Billboard Hot 100   10.0
# 58  2021-04        Asian       Billboard Hot 100    2.0
# 59  2021-04  Mixed Asian       Billboard Hot 100   11.0
# 60  2021-05        Asian       Billboard Hot 100    3.0
# 61  2021-05  Mixed Asian       Billboard Hot 100   23.0
# 62  2021-06        Asian       Billboard Hot 100    8.0
# 63  2021-06  Mixed Asian       Billboard Hot 100   42.0
# 64  2021-07        Asian       Billboard Hot 100   10.0
# 65  2021-07  Mixed Asian       Billboard Hot 100   37.0
# 66  2020-09        Asian    Billboard Global 200    7.0
# 67  2020-09  Mixed Asian    Billboard Global 200    2.0
# 68  2020-10        Asian    Billboard Global 200   32.0
# 69  2020-10  Mixed Asian    Billboard Global 200    4.0
# 70  2020-11        Asian    Billboard Global 200   53.0
# 71  2020-11  Mixed Asian    Billboard Global 200    5.0
# 72  2020-12        Asian    Billboard Global 200   18.0
# 73  2020-12  Mixed Asian    Billboard Global 200    2.0
# 74  2021-01        Asian    Billboard Global 200   26.0
# 75  2021-01  Mixed Asian    Billboard Global 200    5.0
# 76  2021-02        Asian    Billboard Global 200   19.0
# 77  2021-02  Mixed Asian    Billboard Global 200    5.0
# 78  2021-03        Asian    Billboard Global 200   23.0
# 79  2021-03  Mixed Asian    Billboard Global 200    5.0
# 80  2021-04        Asian    Billboard Global 200   13.0
# 81  2021-04  Mixed Asian    Billboard Global 200    9.0
# 82  2021-05        Asian    Billboard Global 200   18.0
# 83  2021-05  Mixed Asian    Billboard Global 200   26.0
# 84  2021-06        Asian    Billboard Global 200   18.0
# 85  2021-06  Mixed Asian    Billboard Global 200   43.0
# 86  2021-07        Asian    Billboard Global 200   22.0
# 87  2021-07  Mixed Asian    Billboard Global 200   34.0

# %%
# Save DataFrame to csv
df_orig_melt.to_csv('./post_processed_data/lineage_over_time.csv')

# %%
# Plot of Asians vs Mixed-Asians through Time
stacked_bar = alt.Chart(df_orig_melt,
                        title="Asians and Mixed-Asians through time"
).mark_bar().encode(
    x=alt.X('month_yr:N', title=None),
    y=alt.Y('sum(value):Q', axis=alt.Axis(grid=False,
                                          title='Number of Time in Chart')),
    column=alt.Column('variable:N', title=None),
    color=alt.Color('lineage:N', 
                    scale=alt.Scale(range=['#D9734E', '#F2B05E']))
).configure_view(
    strokeOpacity=0    
).properties(
    width=180,
    height=300
).configure_axis(
    labelFontSize=12,
    titleFontSize=14
).configure_title(
    fontSize=18, 
    offset=5,                                  
    orient='top', 
    anchor='middle')

stacked_bar

# https://github.com/altair-viz/altair/issues/1679
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 5. Insights Exploration

# %%
# Check spotify top 200 global
sp_g = df_spotify_top200_global.groupby(
    ['month_yr', 'artist2'])['asian'].sum().to_frame()
sp_g = sp_g[sp_g['asian'] != 0].reset_index().set_index('month_yr')

# %%
sp_g.loc['2019-04']
# Out:
#                artist2  asian
# month_yr
# 2019-04      blackpink      5
# 2019-04     bruno mars      3
# 2019-04            bts      9
# 2019-04   dominic fike      1

# %%
# Check spotify top 200 us
sp_us = df_spotify_top200_us.groupby(
    ['month_yr', 'artist2'])['asian'].sum().to_frame()
sp_us = sp_us[sp_us['asian'] != 0].reset_index().set_index('month_yr')

# %%
sp_us.loc['2021-04']
# Out:
#                  artist2  asian
# month_yr
# 2021-04   anderson .paak      5
# 2021-04       bruno mars      9
# 2021-04       conan gray      3
# 2021-04           h.e.r.      1
# 2021-04   olivia rodrigo     10

# %%
df_hot_100[df_hot_100['artist'] == 'bruno mars']
# Out:
#             chartname        date                  song      artist  rank  \
# 0      weekly_hot_100  2011-01-03               Grenade  bruno mars     1
# 9      weekly_hot_100  2011-01-03  Just The Way You Are  bruno mars    10
# 85     weekly_hot_100  2011-01-03             Marry You  bruno mars    86
# 101    weekly_hot_100  2011-01-10               Grenade  bruno mars     2
# 108    weekly_hot_100  2011-01-10  Just The Way You Are  bruno mars     9
# ...               ...         ...                   ...         ...   ...
# 36339  weekly_hot_100  2017-12-18    That's What I Like  bruno mars    40
# 36442  weekly_hot_100  2017-12-25    That's What I Like  bruno mars    43
# 36547  weekly_hot_100  2018-01-01    That's What I Like  bruno mars    48
# 36631  weekly_hot_100  2018-01-08    That's What I Like  bruno mars    32
# 36737  weekly_hot_100  2018-01-15    That's What I Like  bruno mars    38
#
#       month_yr  asian        name            country      lineage  \
# 0      2011-01   True  bruno mars  Filipino American  Mixed Asian
# 9      2011-01   True  bruno mars  Filipino American  Mixed Asian
# 85     2011-01   True  bruno mars  Filipino American  Mixed Asian
# 101    2011-01   True  bruno mars  Filipino American  Mixed Asian
# 108    2011-01   True  bruno mars  Filipino American  Mixed Asian
# ...        ...    ...         ...                ...          ...
# 36339  2017-12   True  bruno mars  Filipino American  Mixed Asian
# 36442  2017-12   True  bruno mars  Filipino American  Mixed Asian
# 36547  2018-01   True  bruno mars  Filipino American  Mixed Asian
# 36631  2018-01   True  bruno mars  Filipino American  Mixed Asian
# 36737  2018-01   True  bruno mars  Filipino American  Mixed Asian
#
#            chart_name
# 0      weekly_hot_100
# 9      weekly_hot_100
# 85     weekly_hot_100
# 101    weekly_hot_100
# 108    weekly_hot_100
# ...               ...
# 36339  weekly_hot_100
# 36442  weekly_hot_100
# 36547  weekly_hot_100
# 36631  weekly_hot_100
# 36737  weekly_hot_100
#
# [342 rows x 11 columns]

# %%
# Check Billboard hot 100
b_hot = df_hot_100.groupby(['month_yr', 'name'])['asian'].sum().to_frame()
b_hot = b_hot[b_hot['asian'] != 0].reset_index().set_index('month_yr')

# %%
b_hot.loc['2019-07':'2019-08']
# Out:
# Empty DataFrame
# Columns: [name, asian]
# Index: []
